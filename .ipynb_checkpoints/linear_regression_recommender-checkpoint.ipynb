# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
import os.path

# %%
s1 = pd.Series([0, 1])
s2 = pd.Series(['a', 'b'])
pd.concat([s1, s2], axis=1)
# Out:
#    0  1
# 0  0  a
# 1  1  b

# %%
col_dict = {}
directory = "tickers-actual"
for filename in os.listdir(directory):
    curr_df = pd.read_csv(directory + '/' + filename)
    print(curr_df['close'])
    #curr_col = curr_df['close']
    #col_dict[filename] = curr_col
col_dict
# Out:
# 0     32.85
# 1     34.53
# 2     33.51
# 3     33.08
# 4     32.70
# 5     31.75
# 6     31.57
# 7     32.81
# 8     33.39
# 9     33.51
# 10    34.17
# 11    35.04
# 12    34.58
# 13    35.47
# 14    36.24
# 15    36.28
# 16    35.94
# 17    36.27
# 18    36.69
# 19    36.19
# 20    35.92
# 21    35.20
# 22    34.96
# 23    35.10
# 24    34.56
# 25    34.89
# 26    34.45
# 27    35.09
# 28    34.91
# 29    34.55
#       ...
# 70    27.96
# 71    28.58
# 72    29.31
# 73    28.94
# 74    28.85
# 75    29.12
# 76    30.42
# 77    29.10
# 78    26.62
# 79    26.60
# 80    26.42
# 81    26.58
# 82    26.36
# 83    26.75
# 84    26.99
# 85    26.92
# 86    26.96
# 87    26.89
# 88    26.86
# 89    26.90
# 90    26.78
# 91    26.60
# 92    26.79
# 93    26.89
# 94    27.63
# 95    27.55
# 96    27.52
# 97    27.33
# 98    27.07
# 99    26.31
# Name: close, Length: 100, dtype: float64
# 0     121.85
# 1     122.28
# 2     120.83
# 3     118.35
# 4     118.47
# 5     116.32
# 6     113.86
# ...

# %%
# make a data frame with 20 of the csvs' CLOSE columns
df_list = []
directory = "tickers-actual"
for filename in os.listdir(directory):
    df_list.append(pd.DataFrame.from_csv(os.join))

# %%
data = pd.read_csv('daily_ACN.csv')
data
# Out:
#      timestamp     open      high       low   close   volume
# 0   2018-02-16  160.960  163.6000  160.8450  162.66  1997852
# 1   2018-02-15  160.390  161.1100  158.1100  161.06  1815828
# 2   2018-02-14  156.010  160.1200  155.1500  159.79  2488848
# 3   2018-02-13  154.200  156.9900  153.9900  156.84  2029692
# 4   2018-02-12  154.670  156.4700  153.9000  154.95  2229969
# 5   2018-02-09  151.690  154.9900  148.7900  153.84  3643267
# 6   2018-02-08  155.310  155.4700  150.3700  150.51  2561721
# 7   2018-02-07  154.220  158.9300  153.0700  155.15  2899684
# 8   2018-02-06  150.290  155.1800  149.4300  154.69  3892071
# 9   2018-02-05  156.120  159.2700  150.7300  151.83  3279792
# 10  2018-02-02  159.980  160.2700  156.6300  156.90  1996693
# 11  2018-02-01  160.155  161.1300  159.5400  160.46  1688252
# 12  2018-01-31  160.090  160.9450  159.7300  160.70  1834626
# 13  2018-01-30  160.960  161.1600  159.1100  159.70  1658261
# ...

# %%
train_x = np.matrix(np.arange(99)).reshape(99, 1)
train_y = np.matrix(data['close'][:99]).reshape(99, 1)

# %%
valid_x = np.matrix(100)
valid_y = np.matrix(data['close'][99])

# %%
lr = LinearRegression()

# %%
lr.fit(train_x, train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
train_y.shape
# Out:
# (99, 1)

# %%
lr.predict(np.matrix(100))
# Out:
# array([[ 135.16392942]])

# %%
135.16392942 - data['close'][99]
# Out:
# -1.6760705800000153
